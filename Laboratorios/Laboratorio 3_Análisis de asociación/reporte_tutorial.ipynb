# %% [markdown]
# # Laboratorio 3 - Análisis de Asociación

# %% [markdown]
# Integrantes:
# - Derek Suarez - B97775
# - Emmanuel Zúñiga - B98729

# %% [markdown]
# ## Tutorial

# %% [markdown]
# ### Carga de Librerias 📚

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ### Carga del Dataset 📅

# %%
df = pd.read_excel('http://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx')

# %%
# Se verifican los primeros 10 registros del dataset
df.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 5 2010-12-01 08:26:00       7.65     17850.0  United Kingdom
# 6 2010-12-01 08:26:00       4.25     17850.0  United Kingdom
# 7 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 8 2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 9 2010-12-01 08:34:00       1.69     13047.0  United Kingdom

# %% [markdown]
# ### Preprocesamiento de Datos 🧹

# %% [markdown]
# A continuación se realiza una limpieza del dataset, entre algunas de ellas se puede destacar: eliminación de espacios en la columna "Description", y eliminación de filas sin número de factura y las transacciones de crédito.

# %%
df['Description'] = df['Description'].str.strip() # Eliminación de espacios
df.dropna(axis=0, subset=['InvoiceNo'], inplace=True)
df['InvoiceNo'] = df['InvoiceNo'].astype('str')
df = df[~df['InvoiceNo'].str.contains('C')]

# %% [markdown]
# Después de la limpieza, se necesita consolidar los artículos en 1 transacción por fila con cada producto 1 codificado en caliente. Con el objetivo de reducir el dataset.

# %%
basket = (df[df['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %% [markdown]
# Se verifican los primeros 10 registros del dataset generado.

# %%
basket.head(10)
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
# 537468                         24.0                         0.0
# 537693                          0.0                         0.0
# 537897                          0.0                         0.0
# 537967                          0.0                         0.0
# 538008                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# 536852                             0.0                              0.0
# 536974                             0.0                              0.0
# 537065                             0.0                              0.0
# 537463                             0.0                              0.0
# 537468                             0.0                              0.0
# 537693                             0.0                              0.0
# 537897                             0.0                              0.0
# 537967                             0.0                              0.0
# 538008                             0.0                              0.0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                 0.0
# 536852                                 0.0
# 536974                                 0.0
# 537065                                 0.0
# 537463                                 0.0
# 537468                                 0.0
# 537693                                 0.0
# 537897                                 0.0
# 537967                                 0.0
# 538008                                 0.0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536370                                       0.0                          0.0
# 536852                                       0.0                          0.0
# 536974                                       0.0                          0.0
# 537065                                       0.0                          0.0
# 537463                                       0.0                          0.0
# 537468                                       0.0                          0.0
# 537693                                       0.0                          0.0
# 537897                                       0.0                          0.0
# 537967                                       0.0                          0.0
# 538008                                       0.0                          0.0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536370                             0.0                                 0.0
# 536852                             0.0                                 0.0
# 536974                             0.0                                 0.0
# 537065                             0.0                                 0.0
# 537463                             0.0                                 0.0
# 537468                             0.0                                 0.0
# 537693                             0.0                                 0.0
# 537897                             0.0                                 0.0
# 537967                             0.0                                 0.0
# 538008                             0.0                                 0.0
#
# Description  12 PENCILS TALL TUBE WOODLAND  ...  WRAP VINTAGE PETALS  DESIGN  \
# InvoiceNo                                   ...
# 536370                                 0.0  ...                          0.0
# 536852                                 0.0  ...                          0.0
# 536974                                 0.0  ...                          0.0
# 537065                                 0.0  ...                          0.0
# 537463                                 0.0  ...                          0.0
# 537468                                 0.0  ...                          0.0
# 537693                                 0.0  ...                          0.0
# 537897                                 0.0  ...                          0.0
# 537967                                 0.0  ...                          0.0
# 538008                                 0.0  ...                          0.0
#
# Description  YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# InvoiceNo
# 536370                                  0.0                              0.0
# 536852                                  0.0                              0.0
# 536974                                  0.0                              0.0
# 537065                                  0.0                              0.0
# 537463                                  0.0                              0.0
# 537468                                  0.0                              0.0
# 537693                                  0.0                              0.0
# 537897                                  0.0                              0.0
# 537967                                  0.0                              0.0
# 538008                                  0.0                              0.0
#
# Description  YELLOW SHARK HELICOPTER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536370                           0.0                        0.0
# 536852                           0.0                        0.0
# 536974                           0.0                        0.0
# 537065                           0.0                        0.0
# 537463                           0.0                        0.0
# 537468                           0.0                        0.0
# 537693                           0.0                        0.0
# 537897                           0.0                        0.0
# 537967                           0.0                        0.0
# 538008                           0.0                        0.0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HERB GARDEN CONTAINER  \
# InvoiceNo
# 536370                             0.0                         0.0
# 536852                             0.0                         0.0
# 536974                             0.0                         0.0
# 537065                             0.0                         0.0
# 537463                             0.0                         0.0
# 537468                             0.0                         0.0
# 537693                             0.0                         0.0
# 537897                             0.0                         0.0
# 537967                             0.0                         0.0
# 538008                             0.0                         0.0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536370                               0.0                             0.0
# 536852                               0.0                             0.0
# 536974                               0.0                             0.0
# 537065                               0.0                             0.0
# 537463                               0.0                             0.0
# 537468                               0.0                             0.0
# 537693                               0.0                             0.0
# 537897                               0.0                             0.0
# 537967                               0.0                             0.0
# 538008                               0.0                             0.0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536370                                   0.0
# 536852                                   0.0
# 536974                                   0.0
# 537065                                   0.0
# 537463                                   0.0
# 537468                                   0.0
# 537693                                   0.0
# 537897                                   0.0
# 537967                                   0.0
# 538008                                   0.0
#
# [10 rows x 1563 columns]

# %% [markdown]
# Se aplica transformación de los datos para convertir cualquier valor mayor a 1, y 0 en 1 y 0 respectivamente.

# %%
def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

basket_sets = basket.applymap(encode_units)
basket_sets.drop('POSTAGE', inplace=True, axis=1)

# %% [markdown]
# Se verifican los primeros 10 registros del dataset

# %%
basket_sets.head(10)
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                            0                           0
# 536852                            0                           0
# 536974                            0                           0
# 537065                            0                           0
# 537463                            0                           0
# 537468                            1                           0
# 537693                            0                           0
# 537897                            0                           0
# 537967                            0                           0
# 538008                            0                           0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                               0                                0
# 536852                               0                                0
# 536974                               0                                0
# 537065                               0                                0
# 537463                               0                                0
# 537468                               0                                0
# 537693                               0                                0
# 537897                               0                                0
# 537967                               0                                0
# 538008                               0                                0
#
# Description  12 PENCIL SMALL TUBE WOODLAND  \
# InvoiceNo
# 536370                                   0
# 536852                                   0
# 536974                                   0
# 537065                                   0
# 537463                                   0
# 537468                                   0
# 537693                                   0
# 537897                                   0
# 537967                                   0
# 538008                                   0
#
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 536370                                         0                            0
# 536852                                         0                            0
# 536974                                         0                            0
# 537065                                         0                            0
# 537463                                         0                            0
# 537468                                         0                            0
# 537693                                         0                            0
# 537897                                         0                            0
# 537967                                         0                            0
# 538008                                         0                            0
#
# Description  12 PENCILS TALL TUBE POSY  12 PENCILS TALL TUBE RED RETROSPOT  \
# InvoiceNo
# 536370                               0                                   0
# 536852                               0                                   0
# 536974                               0                                   0
# 537065                               0                                   0
# 537463                               0                                   0
# 537468                               0                                   0
# 537693                               0                                   0
# 537897                               0                                   0
# 537967                               0                                   0
# 538008                               0                                   0
#
# Description  12 PENCILS TALL TUBE WOODLAND  ...  WRAP VINTAGE PETALS  DESIGN  \
# InvoiceNo                                   ...
# 536370                                   0  ...                            0
# 536852                                   0  ...                            0
# 536974                                   0  ...                            0
# 537065                                   0  ...                            0
# 537463                                   0  ...                            0
# 537468                                   0  ...                            0
# 537693                                   0  ...                            0
# 537897                                   0  ...                            0
# 537967                                   0  ...                            0
# 538008                                   0  ...                            0
#
# Description  YELLOW COAT RACK PARIS FASHION  YELLOW GIANT GARDEN THERMOMETER  \
# InvoiceNo
# 536370                                    0                                0
# 536852                                    0                                0
# 536974                                    0                                0
# 537065                                    0                                0
# 537463                                    0                                0
# 537468                                    0                                0
# 537693                                    0                                0
# 537897                                    0                                0
# 537967                                    0                                0
# 538008                                    0                                0
#
# Description  YELLOW SHARK HELICOPTER  ZINC  STAR T-LIGHT HOLDER  \
# InvoiceNo
# 536370                             0                          0
# 536852                             0                          0
# 536974                             0                          0
# 537065                             0                          0
# 537463                             0                          0
# 537468                             0                          0
# 537693                             0                          0
# 537897                             0                          0
# 537967                             0                          0
# 538008                             0                          0
#
# Description  ZINC FOLKART SLEIGH BELLS  ZINC HERB GARDEN CONTAINER  \
# InvoiceNo
# 536370                               0                           0
# 536852                               0                           0
# 536974                               0                           0
# 537065                               0                           0
# 537463                               0                           0
# 537468                               0                           0
# 537693                               0                           0
# 537897                               0                           0
# 537967                               0                           0
# 538008                               0                           0
#
# Description  ZINC METAL HEART DECORATION  ZINC T-LIGHT HOLDER STAR LARGE  \
# InvoiceNo
# 536370                                 0                               0
# 536852                                 0                               0
# 536974                                 0                               0
# 537065                                 0                               0
# 537463                                 0                               0
# 537468                                 0                               0
# 537693                                 0                               0
# 537897                                 0                               0
# 537967                                 0                               0
# 538008                                 0                               0
#
# Description  ZINC T-LIGHT HOLDER STARS SMALL
# InvoiceNo
# 536370                                     0
# 536852                                     0
# 536974                                     0
# 537065                                     0
# 537463                                     0
# 537468                                     0
# 537693                                     0
# 537897                                     0
# 537967                                     0
# 538008                                     0
#
# [10 rows x 1562 columns]

# %% [markdown]
# ### Algoritmo Apriori 🔢

# %% [markdown]
# Con los datos ya debidamente estructurados, se generan itemsets para aquellos con una frecuencia mayor al 6%

# %%
frequent_itemsets = apriori(basket_sets, min_support=0.06, use_colnames=True)

# %% [markdown]
# El último paso es generar las reglas con su correspondiente apoyo, confianza y elevación:

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)

# %% [markdown]
# Se verifican los primeros 10 registros del dataset.

# %%
rules.head(10)
# Out:
#                       antecedents                     consequents  \
# 0    (ALARM CLOCK BAKELIKE GREEN)     (ALARM CLOCK BAKELIKE PINK)
# 1     (ALARM CLOCK BAKELIKE PINK)    (ALARM CLOCK BAKELIKE GREEN)
# 2    (ALARM CLOCK BAKELIKE GREEN)      (ALARM CLOCK BAKELIKE RED)
# 3      (ALARM CLOCK BAKELIKE RED)    (ALARM CLOCK BAKELIKE GREEN)
# 4     (ALARM CLOCK BAKELIKE PINK)      (ALARM CLOCK BAKELIKE RED)
# 5      (ALARM CLOCK BAKELIKE RED)     (ALARM CLOCK BAKELIKE PINK)
# 6    (CHILDRENS CUTLERY SPACEBOY)  (CHILDRENS CUTLERY DOLLY GIRL)
# 7  (CHILDRENS CUTLERY DOLLY GIRL)    (CHILDRENS CUTLERY SPACEBOY)
# 8          (DOLLY GIRL LUNCH BOX)            (SPACEBOY LUNCH BOX)
# 9            (SPACEBOY LUNCH BOX)          (DOLLY GIRL LUNCH BOX)
#
#    antecedent support  consequent support   support  confidence       lift  \
# 0            0.096939            0.102041  0.073980    0.763158   7.478947
# 1            0.102041            0.096939  0.073980    0.725000   7.478947
# 2            0.096939            0.094388  0.079082    0.815789   8.642959
# 3            0.094388            0.096939  0.079082    0.837838   8.642959
# 4            0.102041            0.094388  0.073980    0.725000   7.681081
# 5            0.094388            0.102041  0.073980    0.783784   7.681081
# 6            0.068878            0.071429  0.063776    0.925926  12.962963
# 7            0.071429            0.068878  0.063776    0.892857  12.962963
# 8            0.099490            0.125000  0.071429    0.717949   5.743590
# 9            0.125000            0.099490  0.071429    0.571429   5.743590
#
#    leverage  conviction
# 0  0.064088    3.791383
# 1  0.064088    3.283859
# 2  0.069932    4.916181
# 3  0.069932    5.568878
# 4  0.064348    3.293135
# 5  0.064348    4.153061
# 6  0.058856   12.535714
# 7  0.058856    8.690476
# 8  0.058992    3.102273
# 9  0.058992    2.101190

# %% [markdown]
# A continuación se realiza un análisis de los datos obtenidos, para ello, se evaluan varias condiciones como lift, support, confidence, entre otros. Esto nos permite intuir aspectos del conjunto de datos.

# %% [markdown]
# Se filtran los registros que tienen un lift mayor o igual a 6, y un valor para cofidence mayor o igual al 80%

# %%
rules[ (rules['lift'] >= 6) &
       (rules['confidence'] >= 0.8) ]
# Out:
#                                           antecedents  \
# 2                        (ALARM CLOCK BAKELIKE GREEN)
# 3                          (ALARM CLOCK BAKELIKE RED)
# 6                        (CHILDRENS CUTLERY SPACEBOY)
# 7                      (CHILDRENS CUTLERY DOLLY GIRL)
# 31                    (SET/6 RED SPOTTY PAPER PLATES)
# 32                    (SET/6 RED SPOTTY PAPER PLATES)
# 33                      (SET/6 RED SPOTTY PAPER CUPS)
# 34  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 35  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 36  (ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...
# 46  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 47  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 48  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
#
#                              consequents  antecedent support  \
# 2             (ALARM CLOCK BAKELIKE RED)            0.096939
# 3           (ALARM CLOCK BAKELIKE GREEN)            0.094388
# 6         (CHILDRENS CUTLERY DOLLY GIRL)            0.068878
# 7           (CHILDRENS CUTLERY SPACEBOY)            0.071429
# 31  (SET/20 RED RETROSPOT PAPER NAPKINS)            0.127551
# 32         (SET/6 RED SPOTTY PAPER CUPS)            0.127551
# 33       (SET/6 RED SPOTTY PAPER PLATES)            0.137755
# 34            (ALARM CLOCK BAKELIKE RED)            0.073980
# 35           (ALARM CLOCK BAKELIKE PINK)            0.079082
# 36          (ALARM CLOCK BAKELIKE GREEN)            0.073980
# 46         (SET/6 RED SPOTTY PAPER CUPS)            0.102041
# 47       (SET/6 RED SPOTTY PAPER PLATES)            0.102041
# 48  (SET/20 RED RETROSPOT PAPER NAPKINS)            0.122449
#
#     consequent support   support  confidence       lift  leverage  conviction
# 2             0.094388  0.079082    0.815789   8.642959  0.069932    4.916181
# 3             0.096939  0.079082    0.837838   8.642959  0.069932    5.568878
# 6             0.071429  0.063776    0.925926  12.962963  0.058856   12.535714
# 7             0.068878  0.063776    0.892857  12.962963  0.058856    8.690476
# 31            0.132653  0.102041    0.800000   6.030769  0.085121    4.336735
# 32            0.137755  0.122449    0.960000   6.968889  0.104878   21.556122
# 33            0.127551  0.122449    0.888889   6.968889  0.104878    7.852041
# 34            0.094388  0.063776    0.862069   9.133271  0.056793    6.565689
# 35            0.102041  0.063776    0.806452   7.903226  0.055706    4.639456
# 36            0.096939  0.063776    0.862069   8.892922  0.056604    6.547194
# 46            0.137755  0.099490    0.975000   7.077778  0.085433   34.489796
# 47            0.127551  0.099490    0.975000   7.644000  0.086474   34.897959
# 48            0.132653  0.099490    0.812500   6.125000  0.083247    4.625850

# %% [markdown]
# Nótese que a partir del filtrado de los datos se puede observar como ciertos items suelen venir en conjunto, por ejemplo, las alarmas verde y rojas suelen comprarse juntas, similarmente con los demás items, donde podemos observar los conjuntos de aquellas transacciones que suelen estar relacionadas.

# %%
print(f"Frecuencia de alarmas verdes: {basket['ALARM CLOCK BAKELIKE GREEN'].sum()}")

print(f"Frecuencia de alarmas rojas: {basket['ALARM CLOCK BAKELIKE RED'].sum()}")
# Out:
# Frecuencia de alarmas verdes: 340.0
# Frecuencia de alarmas rojas: 316.0

# %% [markdown]
# Igualmente, se pueden filtrar los resultados con respecto a la columna 'Country', lo cual, permite observar las combinaciones de items más populares por país. En este caso, se filtraran los resultados para Francia.

# %%
basket2 = (df[df['Country'] =="France"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

basket_sets2 = basket2.applymap(encode_units)
basket_sets2.drop('POSTAGE', inplace=True, axis=1)
frequent_itemsets2 = apriori(basket_sets2, min_support=0.05, use_colnames=True)
rules2 = association_rules(frequent_itemsets2, metric="lift", min_threshold=1)

rules2[ (rules2['lift'] >= 4) &
        (rules2['confidence'] >= 0.5)]
# Out:
#                                           antecedents  \
# 0                        (ALARM CLOCK BAKELIKE GREEN)
# 1                         (ALARM CLOCK BAKELIKE PINK)
# 2                        (ALARM CLOCK BAKELIKE GREEN)
# 3                          (ALARM CLOCK BAKELIKE RED)
# 4                         (ALARM CLOCK BAKELIKE PINK)
# 5                          (ALARM CLOCK BAKELIKE RED)
# 8                        (CHILDRENS CUTLERY SPACEBOY)
# 9                      (CHILDRENS CUTLERY DOLLY GIRL)
# 10                             (DOLLY GIRL LUNCH BOX)
# 11                               (SPACEBOY LUNCH BOX)
# 14                           (LUNCH BAG APPLE DESIGN)
# 15                        (LUNCH BAG SPACEBOY DESIGN)
# 18                      (LUNCH BAG DOLLY GIRL DESIGN)
# 28                               (LUNCH BAG WOODLAND)
# 29                        (LUNCH BAG SPACEBOY DESIGN)
# 38                       (PACK OF 6 SKULL PAPER CUPS)
# 39                     (PACK OF 6 SKULL PAPER PLATES)
# 42                        (PLASTERS IN TIN STRONGMAN)
# 52                         (PLASTERS IN TIN SPACEBOY)
# 53                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 62               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 63                      (SET/6 RED SPOTTY PAPER CUPS)
# 64               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 65                    (SET/6 RED SPOTTY PAPER PLATES)
# 66                    (SET/6 RED SPOTTY PAPER PLATES)
# 67                      (SET/6 RED SPOTTY PAPER CUPS)
# 68  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 69  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...
# 70  (ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...
# 71                       (ALARM CLOCK BAKELIKE GREEN)
# 72                        (ALARM CLOCK BAKELIKE PINK)
# 73                         (ALARM CLOCK BAKELIKE RED)
# 74  (PLASTERS IN TIN SPACEBOY, PLASTERS IN TIN CIR...
# 76  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...
# 77                         (PLASTERS IN TIN SPACEBOY)
# 80  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 81  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 82  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
# 83               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 84                    (SET/6 RED SPOTTY PAPER PLATES)
# 85                      (SET/6 RED SPOTTY PAPER CUPS)
#
#                                           consequents  antecedent support  \
# 0                         (ALARM CLOCK BAKELIKE PINK)            0.096939
# 1                        (ALARM CLOCK BAKELIKE GREEN)            0.102041
# 2                          (ALARM CLOCK BAKELIKE RED)            0.096939
# 3                        (ALARM CLOCK BAKELIKE GREEN)            0.094388
# 4                          (ALARM CLOCK BAKELIKE RED)            0.102041
# 5                         (ALARM CLOCK BAKELIKE PINK)            0.094388
# 8                      (CHILDRENS CUTLERY DOLLY GIRL)            0.068878
# 9                        (CHILDRENS CUTLERY SPACEBOY)            0.071429
# 10                               (SPACEBOY LUNCH BOX)            0.099490
# 11                             (DOLLY GIRL LUNCH BOX)            0.125000
# 14                        (LUNCH BAG SPACEBOY DESIGN)            0.125000
# 15                           (LUNCH BAG APPLE DESIGN)            0.119898
# 18                        (LUNCH BAG SPACEBOY DESIGN)            0.084184
# 28                        (LUNCH BAG SPACEBOY DESIGN)            0.117347
# 29                               (LUNCH BAG WOODLAND)            0.119898
# 38                     (PACK OF 6 SKULL PAPER PLATES)            0.063776
# 39                       (PACK OF 6 SKULL PAPER CUPS)            0.056122
# 42                    (PLASTERS IN TIN CIRCUS PARADE)            0.081633
# 52                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.137755
# 53                         (PLASTERS IN TIN SPACEBOY)            0.170918
# 62                      (SET/6 RED SPOTTY PAPER CUPS)            0.132653
# 63               (SET/20 RED RETROSPOT PAPER NAPKINS)            0.137755
# 64                    (SET/6 RED SPOTTY PAPER PLATES)            0.132653
# 65               (SET/20 RED RETROSPOT PAPER NAPKINS)            0.127551
# 66                      (SET/6 RED SPOTTY PAPER CUPS)            0.127551
# 67                    (SET/6 RED SPOTTY PAPER PLATES)            0.137755
# 68                         (ALARM CLOCK BAKELIKE RED)            0.073980
# 69                        (ALARM CLOCK BAKELIKE PINK)            0.079082
# 70                       (ALARM CLOCK BAKELIKE GREEN)            0.073980
# 71  (ALARM CLOCK BAKELIKE PINK, ALARM CLOCK BAKELI...            0.096939
# 72  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...            0.102041
# 73  (ALARM CLOCK BAKELIKE GREEN, ALARM CLOCK BAKEL...            0.094388
# 74                 (PLASTERS IN TIN WOODLAND ANIMALS)            0.089286
# 76                         (PLASTERS IN TIN SPACEBOY)            0.102041
# 77  (PLASTERS IN TIN CIRCUS PARADE, PLASTERS IN TI...            0.137755
# 80                      (SET/6 RED SPOTTY PAPER CUPS)            0.102041
# 81                    (SET/6 RED SPOTTY PAPER PLATES)            0.102041
# 82               (SET/20 RED RETROSPOT PAPER NAPKINS)            0.122449
# 83  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...            0.132653
# 84  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.127551
# 85  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...            0.137755
#
#     consequent support   support  confidence       lift  leverage  conviction
# 0             0.102041  0.073980    0.763158   7.478947  0.064088    3.791383
# 1             0.096939  0.073980    0.725000   7.478947  0.064088    3.283859
# 2             0.094388  0.079082    0.815789   8.642959  0.069932    4.916181
# 3             0.096939  0.079082    0.837838   8.642959  0.069932    5.568878
# 4             0.094388  0.073980    0.725000   7.681081  0.064348    3.293135
# 5             0.102041  0.073980    0.783784   7.681081  0.064348    4.153061
# 8             0.071429  0.063776    0.925926  12.962963  0.058856   12.535714
# 9             0.068878  0.063776    0.892857  12.962963  0.058856    8.690476
# 10            0.125000  0.071429    0.717949   5.743590  0.058992    3.102273
# 11            0.099490  0.071429    0.571429   5.743590  0.058992    2.101190
# 14            0.119898  0.063776    0.510204   4.255319  0.048788    1.796875
# 15            0.125000  0.063776    0.531915   4.255319  0.048788    1.869318
# 18            0.119898  0.051020    0.606061   5.054803  0.040927    2.234105
# 28            0.119898  0.063776    0.543478   4.532840  0.049706    1.927843
# 29            0.117347  0.063776    0.531915   4.532840  0.049706    1.885668
# 38            0.056122  0.051020    0.800000  14.254545  0.047441    4.719388
# 39            0.063776  0.051020    0.909091  14.254545  0.047441   10.298469
# 42            0.168367  0.058673    0.718750   4.268939  0.044929    2.956916
# 52            0.170918  0.104592    0.759259   4.442233  0.081047    3.443878
# 53            0.137755  0.104592    0.611940   4.442233  0.081047    2.221939
# 62            0.137755  0.102041    0.769231   5.584046  0.083767    3.736395
# 63            0.132653  0.102041    0.740741   5.584046  0.083767    3.345481
# 64            0.127551  0.102041    0.769231   6.030769  0.085121    3.780612
# 65            0.132653  0.102041    0.800000   6.030769  0.085121    4.336735
# 66            0.137755  0.122449    0.960000   6.968889  0.104878   21.556122
# 67            0.127551  0.122449    0.888889   6.968889  0.104878    7.852041
# 68            0.094388  0.063776    0.862069   9.133271  0.056793    6.565689
# 69            0.102041  0.063776    0.806452   7.903226  0.055706    4.639456
# 70            0.096939  0.063776    0.862069   8.892922  0.056604    6.547194
# 71            0.073980  0.063776    0.657895   8.892922  0.056604    2.706829
# 72            0.079082  0.063776    0.625000   7.903226  0.055706    2.455782
# 73            0.073980  0.063776    0.675676   9.133271  0.056793    2.855230
# 74            0.170918  0.068878    0.771429   4.513433  0.053617    3.627232
# 76            0.137755  0.068878    0.675000   4.900000  0.054821    2.653061
# 77            0.102041  0.068878    0.500000   4.900000  0.054821    1.795918
# 80            0.137755  0.099490    0.975000   7.077778  0.085433   34.489796
# 81            0.127551  0.099490    0.975000   7.644000  0.086474   34.897959
# 82            0.132653  0.099490    0.812500   6.125000  0.083247    4.625850
# 83            0.122449  0.099490    0.750000   6.125000  0.083247    3.510204
# 84            0.102041  0.099490    0.780000   7.644000  0.086474    4.081633
# 85            0.102041  0.099490    0.722222   7.077778  0.085433    3.232653

# %% [markdown]
# ¿Qué nos dice esta tabla?
# A partir de los resultados presentados anteriormente, se puede verificar como en Francia existe una preferencia por las alarmas, independientemente de su color. Lo usual, es que en Francia se suele comprar en conjunto alarmas verdes y alarmas rosas.

# %% [markdown]
# ## MLextend Apriori

# %% [markdown]
# A continuación, se presentan los ejemplos de uso para el algoritmo apriori según la libreria MLextend.

# %% [markdown]
# ### Carga de Librerias 📚

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

# %% [markdown]
# ### Carga del Dataset 📅

# %% [markdown]
# A continuación se genera un dataset con nombres de videojuegos.

# %%
dataset = [['God of War: Ragnarök', 'Elden Ring', 'Red Dead Redemption: II', 'Forza: Horizon', 'Blasphemous', 'Cyberpunk 2077'],
          ['Hogwarts Legacy', 'Elden Ring', 'Red Dead Redemption: II', 'Forza: Horizon', 'Blasphemous', 'Cyberpunk 2077'],
          ['God of War: Ragnarök', 'Final Fantasy XVI', 'Forza: Horizon', 'Blasphemous'],
          ['God of War: Ragnarök', 'Diablo IV', 'Ark 2', 'Forza: Horizon', 'Cyberpunk 2077'],
          ['Ark 2', 'Elden Ring', 'Elden Ring', 'Forza: Horizon', 'Minecraft', 'Blasphemous']]

# %% [markdown]
# A continuación, se verifican las apariciones de los videojuegos para cada "transacción", puede determinarse la aparición de cada videojuego en las transacciones según su valor, ya sea (True o False).

# %%
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#    Ark 2  Blasphemous  Cyberpunk 2077  Diablo IV  Elden Ring  \
# 0  False         True            True      False        True
# 1  False         True            True      False        True
# 2  False         True           False      False       False
# 3   True        False            True       True       False
# 4   True         True           False      False        True
#
#    Final Fantasy XVI  Forza: Horizon  God of War: Ragnarök  Hogwarts Legacy  \
# 0              False            True                  True            False
# 1              False            True                 False             True
# 2               True            True                  True            False
# 3              False            True                  True            False
# 4              False            True                 False            False
#
#    Ice cream  Red Dead Redemption: II
# 0      False                     True
# 1      False                     True
# 2      False                    False
# 3      False                    False
# 4       True                    False

# %% [markdown]
# Posteriormente, verificamos aquellos items com un soporte de al menos 60%

# %%
apriori(df, min_support=0.6, use_colnames=True)
# Out:
#     support                                   itemsets
# 0       0.8                              (Blasphemous)
# 1       0.6                           (Cyberpunk 2077)
# 2       0.6                               (Elden Ring)
# 3       1.0                           (Forza: Horizon)
# 4       0.6                     (God of War: Ragnarök)
# 5       0.6                  (Blasphemous, Elden Ring)
# 6       0.8              (Forza: Horizon, Blasphemous)
# 7       0.6           (Forza: Horizon, Cyberpunk 2077)
# 8       0.6               (Forza: Horizon, Elden Ring)
# 9       0.6     (Forza: Horizon, God of War: Ragnarök)
# 10      0.6  (Forza: Horizon, Blasphemous, Elden Ring)

# %% [markdown]
# A partir de los datos mostrados anteriormente, se puede observar como Blasphemous y Elden Ring suelen ser comprados en conjuntos, similarmente a Forza: Horizon y Blasphemous, entre otros.

# %% [markdown]
# En caso de que se quiere ahorrar espacio, resulta útil representar los datos transaccionales en formato sparse.

# %%
oht_ary = te.fit(dataset).transform(dataset, sparse=True)
sparse_df = pd.DataFrame.sparse.from_spmatrix(oht_ary, columns=te.columns_)
sparse_df
# Out:
#    Ark 2  Blasphemous  Cyberpunk 2077  Diablo IV  Elden Ring  \
# 0      0            1               1          0           1
# 1      0            1               1          0           1
# 2      0            1               0          0           0
# 3      1            0               1          1           0
# 4      1            1               0          0           1
#
#    Final Fantasy XVI  Forza: Horizon  God of War: Ragnarök  Hogwarts Legacy  \
# 0                  0            True                     1                0
# 1                  0            True                     0                1
# 2                  1            True                     1                0
# 3                  0            True                     1                0
# 4                  0            True                     0                0
#
#    Ice cream  Red Dead Redemption: II
# 0          0                        1
# 1          0                        1
# 2          0                        0
# 3          0                        0
# 4          1                        0

# %%
apriori(sparse_df, min_support=0.6, use_colnames=True)
# Out:
#     support                                   itemsets
# 0       0.8                              (Blasphemous)
# 1       0.6                           (Cyberpunk 2077)
# 2       0.6                               (Elden Ring)
# 3       1.0                           (Forza: Horizon)
# 4       0.6                     (God of War: Ragnarök)
# 5       0.6                  (Blasphemous, Elden Ring)
# 6       0.8              (Forza: Horizon, Blasphemous)
# 7       0.6           (Forza: Horizon, Cyberpunk 2077)
# 8       0.6               (Forza: Horizon, Elden Ring)
# 9       0.6     (Forza: Horizon, God of War: Ragnarök)
# 10      0.6  (Forza: Horizon, Blasphemous, Elden Ring)

# %% [markdown]
# Similarmente a la tabla presentada más arriba, aqui se muestran aquellos itemsets con un soporte de al menos el 60% en el dataset transaccional.
#
# La implementación de estás metodologías, permiten el estudio exhaustivo de datasets transaccionales, esto permite entre otros casos: aplicación de promociones, distribución de los items en la tiendra, entre otros.
